# %%
import psycopg2
import matplotlib
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import re

# %%
pd.set_option('display.max_rows', 200)

# %%
raw_perf_df = pd.read_csv('../data/performances.csv');
news_df = pd.read_csv('../data/news.csv');

perf_df = raw_perf_df.join(news_df.set_index('url'), on='url')
raw_perf_df.size
perf_df.head(10)
# Out:
#                                                  url strategy     symbol  \
# 0  https://binance.zendesk.com/hc/en-us/articles/...  highest    BNBUSDT
# 1  https://binance.zendesk.com/hc/en-us/articles/...  highest    ONEUSDT
# 2  https://binance.zendesk.com/hc/en-us/articles/...  highest  THETAUSDT
# 3  https://binance.zendesk.com/hc/en-us/articles/...  highest    LSKUSDT
# 4  https://binance.zendesk.com/hc/en-us/articles/...  highest    XMRUSDT
#
#    performance           extractor
# 0     0.506597             onlyBnb
# 1     0.232900  relatedAgainstUsdt
# 2     0.438600  relatedAgainstUsdt
# 3     0.165701  relatedAgainstUsdt
# 4    -0.004999  relatedAgainstUsdt
#     id                                              title  \
# 0  324             Notice of Temporary System Maintenance
# 1  325  Binance Futures Will Launch QTUM/USDT Perpetua...
# 2  326  Binance Adds Additional Trading Pairs for STRA...
# 3  327                 IOTX Competition Has Now Concluded
# 4  328  Binance Adds BUSD Margin Pairs for ETC, TRX an...
#
#                      time                                            content  \
# 0  2020-02-19 11:34:42+00  Fellow Binancians,\nBinance is undergoing temp...
# 1  2020-02-19 09:31:00+00  Fellow Binancians,\nBinance Futures will launc...
# 2  2020-02-19 06:05:16+00  Fellow Binancians,\nBinance will open trading ...
# 3  2020-02-28 12:13:15+00  Fellow Binancians,\nThe IOTX competition has n...
# 4  2020-02-27 05:57:23+00  Fellow Binancians,\nBinance’s Margin Trading p...
#
#                                                  url
# 0  https://binance.zendesk.com/hc/en-us/articles/...
# 1  https://binance.zendesk.com/hc/en-us/articles/...
# 2  https://binance.zendesk.com/hc/en-us/articles/...
# 3  https://binance.zendesk.com/hc/en-us/articles/...
# 4  https://binance.zendesk.com/hc/en-us/articles/...
#                                                  url strategy     symbol  \
# 0  https://binance.zendesk.com/hc/en-us/articles/...  highest    BNBUSDT
# 1  https://binance.zendesk.com/hc/en-us/articles/...  highest    ONEUSDT
# 2  https://binance.zendesk.com/hc/en-us/articles/...  highest  THETAUSDT
# 3  https://binance.zendesk.com/hc/en-us/articles/...  highest    LSKUSDT
# 4  https://binance.zendesk.com/hc/en-us/articles/...  highest    XMRUSDT
# 5  https://binance.zendesk.com/hc/en-us/articles/...  highest    BTCUSDT
# 6  https://binance.zendesk.com/hc/en-us/articles/...  highest   BUSDUSDT
# 7  https://binance.zendesk.com/hc/en-us/articles/...  highest    BNBUSDT
# 8  https://binance.zendesk.com/hc/en-us/articles/...  highest   TROYUSDT
# 9  https://binance.zendesk.com/hc/en-us/articles/...  highest   CTSIUSDT
#
#    performance           extractor   id  \
# 0     0.506597             onlyBnb  142
# 1     0.232900  relatedAgainstUsdt  250
# 2     0.438600  relatedAgainstUsdt  250
# 3     0.165701  relatedAgainstUsdt  250
# 4    -0.004999  relatedAgainstUsdt  258
# 5     4.337170  relatedAgainstUsdt  259
# 6    -0.179978  relatedAgainstUsdt  259
# 7     6.273633  relatedAgainstUsdt  210
# 8    -0.200000  relatedAgainstUsdt  250
# 9          NaN  relatedAgainstUsdt  213
#
#                                                title                    time  \
# 0  Binance Lists Second BEP2 Community Listing Pr...  2019-08-23 13:41:05+00
# 1  Binance Has Distributed the Second Batch of St...  2020-04-20 11:29:57+00
# 2  Binance Has Distributed the Second Batch of St...  2020-04-20 11:29:57+00
# 3  Binance Has Distributed the Second Batch of St...  2020-04-20 11:29:57+00
# 4  Binance Savings Adds IOST and XMR to Flexible ...  2020-04-16 09:26:56+00
# 5              Binance Will List Rupiah Token (IDRT)  2020-04-16 06:09:44+00
# 6              Binance Will List Rupiah Token (IDRT)  2020-04-16 06:09:44+00
# 7  Introducing the Cartesi (CTSI) Token Sale on B...  2020-04-13 09:53:13+00
# 8  Binance Has Distributed the Second Batch of St...  2020-04-20 11:29:57+00
# 9  Play Cartesi’s Creepts Game to Enter a $50,000...  2020-04-16 01:56:22+00
#
#                                              content
# 0  Fellow Binancians,\nFor the second month of th...
# 1  Fellow Binancians,\nBinance has completed the ...
# 2  Fellow Binancians,\nBinance has completed the ...
# 3  Fellow Binancians,\nBinance has completed the ...
# 4  Fellow Binancians,\nBinance Savings has added ...
# 5  Fellow Binancians,\nBinance will list Rupiah T...
# 6  Fellow Binancians,\nBinance will list Rupiah T...
# 7  Fellow Binancians,\nBinance is excited to anno...
# 8  Fellow Binancians,\nBinance has completed the ...
# 9  With Cartesi being announced as the next proje...

# %%
meaningless_words = ['to', 'and', 'will', 'of', 'the', 'for', 'on', '', 'by', 'a', 'an', 'as', 'in', 'be', 'has', 'have']
def format_title(title):
    clean_title = re.sub('[^A-Za-z0-9 ]+', ' ', title.lower())
    without_duplicate_space_title = re.sub(' +', ' ',clean_title)
    words = clean_title.split(' ')
    uniq_words = list(set(words))
    meaningful_words = [word for word in uniq_words if word not in meaningless_words]
    return meaningful_words

# %%
def mean_5_bests(series):
    """Take the average of the 5 bests element of the serie"""
    if len(series) == 0:
        return null
    bests = sorted(series)[-5:]
    return sum(bests)/len(bests)

assert mean_5_bests([5, 3, 4, 2, 1, 3, 3, 3, 3]) == (5+4+3+3+3)/5

# %%
word_df = perf_df.copy()
word_df['words'] = word_df['title'].apply(format_title)

# %%
words_exploded_df = word_df \
    .explode('words') \
    .groupby(['words', 'extractor', 'strategy', 'symbol']) \
    .agg(
        count=('words', 'count'), 
        computed_perf=('performance', 'mean')
    ).sort_values(['computed_perf'], ascending=True)

# %%
words_exploded_df.head(10)
# Out:
#                                                 count  computed_perf
# words   extractor          strategy   symbol
# trading relatedAgainstUsdt follower10 DENTUSDT      2     -11.803651
# pairs   relatedAgainstUsdt follower10 DENTUSDT      2     -11.803651
# removal relatedAgainstUsdt follower10 DENTUSDT      1     -11.803651
# notice  relatedAgainstUsdt follower10 DENTUSDT      1     -11.803651
#                                       KEYUSDT       1     -11.734025
# 03      relatedAgainstUsdt follower10 KEYUSDT       1     -11.734025
# removal relatedAgainstUsdt follower10 KEYUSDT       1     -11.734025
# 04      relatedAgainstUsdt follower10 KEYUSDT       1     -11.734025
# trading relatedAgainstUsdt follower10 KEYUSDT       2     -11.734025
# 2020    relatedAgainstUsdt follower10 KEYUSDT       1     -11.734025

# %%
array = words_exploded_df.reset_index()
strategyFilter = array['strategy'].str.startswith('charly_')
extractorFilter =  array['extractor'] == 'relatedAgainstUsdt'
countFilter = array['count'] > 2
filtered_array = array[
    strategyFilter & 
    extractorFilter &
    countFilter
]\
.groupby(['words', 'extractor', 'strategy', 'symbol'])\
.agg(
        count=('count', 'sum'), 
        computed_perf=('computed_perf', 'mean')
    )\
.sort_values(['computed_perf'], ascending=False)
filtered_array.head(10)
# Out:
#                                                            count  \
# words       extractor          strategy         symbol
# binance     relatedAgainstUsdt charly_S_30W15L5 TFUELUSDT      3
# batch       relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# rewards     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# staking     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# 2020        relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# distributed relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# second      relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      3
# binance     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT      4
# batch       relatedAgainstUsdt charly_S_10W15L5 THETAUSDT      3
# second      relatedAgainstUsdt charly_S_10W15L5 THETAUSDT      3
#
#                                                            computed_perf
# words       extractor          strategy         symbol
# binance     relatedAgainstUsdt charly_S_30W15L5 TFUELUSDT       4.498974
# batch       relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# rewards     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# staking     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# 2020        relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# distributed relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# second      relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.642558
# binance     relatedAgainstUsdt charly_S_10W15L5 TFUELUSDT       3.493854
# batch       relatedAgainstUsdt charly_S_10W15L5 THETAUSDT       3.482438
# second      relatedAgainstUsdt charly_S_10W15L5 THETAUSDT       3.482438

# %%
#filtered_array.plot(x='words', y='computed_perf')

# %%
hot_words = ['listing', 'list', 'trading']
wordFilter = perf_df['title'].apply(format_title).apply(lambda words: any(word in hot_words for word in words))

strategyFilter = perf_df['strategy'] == 'charly_S30W5L5'
extractorFilter =  perf_df['extractor'] == 'relatedAgainstUsdt'

perf_ser = perf_df[strategyFilter & extractorFilter& wordFilter]['performance']
print(perf_ser.describe())
perf_ser.apply(lambda p: 1+p/100).prod()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: performance, dtype: float64
# 1.0
